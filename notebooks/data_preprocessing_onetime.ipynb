# %%
import sys
sys.path.append('../src')

# %%
from data_preprocessing import convert_citibike_zip_to_parquet, load_parquet_in_spark, fetch_data

# %%
# Define base paths
base_zip_path = '../data/raw/'
processed_data_output_path = '../data/processed/citibike'

# Loop over the years
for year in [2021, 2022]:
    # Create the path for the current year's zip file
    citibike_data_zip_path = f'{base_zip_path}{year}-citibike-tripdata.zip'
    
    # Call the conversion function with the dynamic path
    convert_citibike_zip_to_parquet(citibike_data_zip_path, processed_data_output_path)
# Out:
# C:\Users\azizt\Documents\case studies\Citibike_insurance_case_study\notebooks\../src\data_preprocessing.py:78: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   yield pd.read_csv(csv_file), csv_filename
# C:\Users\azizt\Documents\case studies\Citibike_insurance_case_study\notebooks\../src\data_preprocessing.py:78: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   yield pd.read_csv(csv_file), csv_filename
# C:\Users\azizt\Documents\case studies\Citibike_insurance_case_study\notebooks\../src\data_preprocessing.py:78: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   yield pd.read_csv(csv_file), csv_filename
# C:\Users\azizt\Documents\case studies\Citibike_insurance_case_study\notebooks\../src\data_preprocessing.py:78: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
# ...
